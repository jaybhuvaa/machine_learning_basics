# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('emp.csv')
data=pd.DataFrame(data)
data
# Out:
#     ID  Experience Department  Salary
# 0    1           5         IT   36000
# 1    2           6         IT   56000
# 2    3           2         IT  150000
# 3    4           5         IT   25000
# 4    5           7         IT   89000
# 5    6          15         IT  111000
# 6    7           2         IT   23000
# 7    8           3         IT   12000
# 8    9          18         IT  569023
# 9   10          10         CE  458962
# 10  11          11         CE  155112
# 11  12          26         CE   15151
# 12  13          30         CE  758963
# 13  14           1         CE    2300
# 14  15           5         CE  256663
# 15  16           6         CE   55456
# 16  17           4         EC   15666
# 17  18           8         EC   15195
# 18  19           9         EC   78963
# 19  20          23         EC   12355

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

data['Department']=enc.fit_transform(data['Department'])
data['Department'].unique()
data
# Out:
#     ID  Experience  Department  Salary
# 0    1           5           2   36000
# 1    2           6           2   56000
# 2    3           2           2  150000
# 3    4           5           2   25000
# 4    5           7           2   89000
# 5    6          15           2  111000
# 6    7           2           2   23000
# 7    8           3           2   12000
# 8    9          18           2  569023
# 9   10          10           0  458962
# 10  11          11           0  155112
# 11  12          26           0   15151
# 12  13          30           0  758963
# 13  14           1           0    2300
# 14  15           5           0  256663
# 15  16           6           0   55456
# 16  17           4           1   15666
# 17  18           8           1   15195
# 18  19           9           1   78963
# 19  20          23           1   12355

# %%
X=data[['Experience','Department']]
y=data['Salary']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
ln=LinearRegression()
ln
# Out:
# LinearRegression()

# %%
ln.fit(X_train,y_train)
ln
# Out:
# LinearRegression()

# %%
sal=y_pred=ln.predict([[2,5]])
sal
# Out:
# C:\Users\darsh\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-163032.88911001])

# %%
plt.scatter(data['Experience'],data['Department'])
plt.show()
