# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %%
data=pd.read_csv('most_runs_average_strikerate.csv')
data=pd.DataFrame(data)
data
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [516 rows x 6 columns]

# %%
x=data['total_runs']
y=data['out']

# %%
plt.scatter(x,y)
plt.xlabel('total_runs')
plt.ylabel('out')
# Out:
# Text(0, 0.5, 'out')

# %%
kmeans=KMeans(n_clusters=3)
kmeans
# Out:
# KMeans(n_clusters=3)

# %%
cluster_labels=kmeans.fit_predict(data[['total_runs','out']])
data['cluster']=cluster_labels
data
# Out:
# C:\Users\darsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\darsh\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:110: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\darsh\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 199, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\darsh\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
# ...

# %%
c1=data[data.cluster==0]
c2=data[data.cluster==1]
c3=data[data.cluster==2]

# %%
c1
# Out:
#              batsman  total_runs  out  numberofballs    average  strikerate  \
# 75         KH Pandya         897   32            609  28.031250  147.290640
# 76          HH Gibbs         886   32            802  27.687500  110.473815
# 77         STR Binny         880   44            683  20.000000  128.843338
# 78        EJG Morgan         854   38            702  22.473684  121.652422
# 79   Harbhajan Singh         831   56            597  14.839286  139.195980
# ..               ...         ...  ...            ...        ...         ...
# 511         ND Doshi           0    1             13   0.000000    0.000000
# 512          J Denly           0    1              1   0.000000    0.000000
# 513          S Ladda           0    2              9   0.000000    0.000000
# 514   V Pratap Singh           0    1              1   0.000000    0.000000
# 515        S Kaushik           0    1              1   0.000000    0.000000
#
#      cluster
# 75         0
# 76         0
# ...

# %%
c2
# Out:
#              batsman  total_runs  out  numberofballs    average  strikerate  \
# 15       BB McCullum        2886  106           2185  27.226415  132.082380
# 16          PA Patel        2864  127           2352  22.551181  121.768707
# 17         MK Pandey        2855   95           2352  30.052632  121.386054
# 18        KA Pollard        2772  102           1879  27.176471  147.525279
# 19      Yuvraj Singh        2755  109           2121  25.275229  129.891561
# 20          V Sehwag        2728   98           1746  27.836735  156.242841
# 21           M Vijay        2589   93           2104  27.838710  123.051331
# 22          SE Marsh        2489   65           1866  38.292308  133.386924
# 23         JH Kallis        2427   89           2219  27.269663  109.373592
# 24          DR Smith        2385   81           1758  29.444444  135.665529
# 25      SR Tendulkar        2334   71           1943  32.873239  120.123520
# ...

# %%
c3
# Out:
#            batsman  total_runs  out  numberofballs    average  strikerate  \
# 0          V Kohli        5426  152           4111  35.697368  131.987351
# 1         SK Raina        5386  160           3916  33.662500  137.538304
# 2        RG Sharma        4902  161           3742  30.447205  130.999466
# 3        DA Warner        4717  114           3292  41.377193  143.286756
# 4         S Dhawan        4601  137           3665  33.583942  125.538881
# 5         CH Gayle        4525  110           2972  41.136364  152.254374
# 6         MS Dhoni        4450  118           3206  37.711864  138.802246
# 7       RV Uthappa        4420  156           3381  28.333333  130.730553
# 8   AB de Villiers        4414  104           2902  42.442308  152.101999
# 9        G Gambhir        4219  134           3400  31.485075  124.088235
# 10       AM Rahane        3834  117           3133  32.769231  122.374721
# 11      KD Karthik        3669  138           2813  26.586957  130.430146
# ...

# %%
plt.scatter(c1['total_runs'],c1['out'],color='red')
plt.scatter(c2['total_runs'],c2['out'],color='blue')
plt.scatter(c3['total_runs'],c3['out'],color='green')

# %%
max_run=data['total_runs'].max()
print(max_run)
max_out=data['out'].max()
print(max_out)
# Out:
# 5426
# 161

# %%
data['total_runs']=data['total_runs']/max_run
data['out']=data['out']/max_out
data
# Out:
#             batsman  total_runs       out  numberofballs    average  \
# 0           V Kohli    1.000000  0.944099           4111  35.697368
# 1          SK Raina    0.992628  0.993789           3916  33.662500
# 2         RG Sharma    0.903428  1.000000           3742  30.447205
# 3         DA Warner    0.869333  0.708075           3292  41.377193
# 4          S Dhawan    0.847954  0.850932           3665  33.583942
# ..              ...         ...       ...            ...        ...
# 511        ND Doshi    0.000000  0.006211             13   0.000000
# 512         J Denly    0.000000  0.006211              1   0.000000
# 513         S Ladda    0.000000  0.012422              9   0.000000
# 514  V Pratap Singh    0.000000  0.006211              1   0.000000
# 515       S Kaushik    0.000000  0.006211              1   0.000000
#
#      strikerate
# 0    131.987351
# 1    137.538304
# 2    130.999466
# 3    143.286756
# 4    125.538881
# ..          ...
# 511    0.000000
# ...

# %%
km=KMeans(n_clusters=3)
km
# Out:
# KMeans(n_clusters=3)

# %%
cluster_labels=km.fit_predict(data[['total_runs','out']])
data['cluster']=cluster_labels
data
# Out:
# C:\Users\darsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\darsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
#             batsman  total_runs       out  numberofballs    average  \
# 0           V Kohli    1.000000  0.944099           4111  35.697368
# 1          SK Raina    0.992628  0.993789           3916  33.662500
# 2         RG Sharma    0.903428  1.000000           3742  30.447205
# 3         DA Warner    0.869333  0.708075           3292  41.377193
# 4          S Dhawan    0.847954  0.850932           3665  33.583942
# ...

# %%
c1=data[data.cluster==0]
c2=data[data.cluster==1]
c3=data[data.cluster==2]
c1
# Out:
#             batsman  total_runs       out  numberofballs    average  \
# 93         SA Yadav    0.112053  0.180124            465  20.965517
# 94         JD Ryder    0.111316  0.180124            456  20.827586
# 95           P Shaw    0.111316  0.149068            423  25.166667
# 97          HM Amla    0.106340  0.080745            407  44.384615
# 98        V Shankar    0.103760  0.105590            416  33.117647
# ..              ...         ...       ...            ...        ...
# 511        ND Doshi    0.000000  0.006211             13   0.000000
# 512         J Denly    0.000000  0.006211              1   0.000000
# 513         S Ladda    0.000000  0.012422              9   0.000000
# 514  V Pratap Singh    0.000000  0.006211              1   0.000000
# 515       S Kaushik    0.000000  0.006211              1   0.000000
#
#      strikerate  cluster
# 93   130.752688        0
# 94   132.456140        0
# 95   142.789598        0
# 97   141.769042        0
# ...

# %%
c2
# Out:
#            batsman  total_runs       out  numberofballs    average  \
# 0          V Kohli    1.000000  0.944099           4111  35.697368
# 1         SK Raina    0.992628  0.993789           3916  33.662500
# 2        RG Sharma    0.903428  1.000000           3742  30.447205
# 3        DA Warner    0.869333  0.708075           3292  41.377193
# 4         S Dhawan    0.847954  0.850932           3665  33.583942
# 5         CH Gayle    0.833948  0.683230           2972  41.136364
# 6         MS Dhoni    0.820125  0.732919           3206  37.711864
# 7       RV Uthappa    0.814596  0.968944           3381  28.333333
# 8   AB de Villiers    0.813491  0.645963           2902  42.442308
# 9        G Gambhir    0.777553  0.832298           3400  31.485075
# 10       AM Rahane    0.706598  0.726708           3133  32.769231
# 11      KD Karthik    0.676189  0.857143           2813  26.586957
# 12       SR Watson    0.661629  0.714286           2566  31.217391
# ...

# %%
c3
# Out:
#           batsman  total_runs       out  numberofballs    average  strikerate  \
# 22       SE Marsh    0.458717  0.403727           1866  38.292308  133.386924
# 24       DR Smith    0.439550  0.503106           1758  29.444444  135.665529
# 25   SR Tendulkar    0.430151  0.440994           1943  32.873239  120.123520
# 26      SV Samson    0.408220  0.490683           1693  28.037975  130.832841
# 27       R Dravid    0.400663  0.478261           1877  28.233766  115.823122
# ..            ...         ...       ...            ...        ...         ...
# 90       AM Nayar    0.123848  0.242236            574  17.230769  117.073171
# 91      GJ Bailey    0.122189  0.180124            543  22.862069  122.099448
# 92      BA Stokes    0.118135  0.186335            481  21.366667  133.264033
# 96      PP Chawla    0.107630  0.310559            519  11.680000  112.524085
# 102      DJ Hooda    0.096941  0.204969            413  15.939394  127.360775
#
#      cluster
# 22         2
# ...

# %%
plt.scatter(c1['total_runs'],c1['out'],color='red')
plt.scatter(c2['total_runs'],c2['out'],color='blue')
plt.scatter(c3['total_runs'],c3['out'],color='green')

# %%
nd=[[0.8,0.8]]*3
c=km.fit_predict(nd)
c
# Out:
# C:\Users\darsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\darsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\darsh\anaconda3\Lib\site-packages\sklearn\base.py:1151: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# array([0, 0, 0])
